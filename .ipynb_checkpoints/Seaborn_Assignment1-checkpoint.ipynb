# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ## Data Description
#
# - Survival : 0 = No, 1 = Yes
# - pclass(Ticket Class) : 1 = 1st, 2 = 2nd, 3 = 3rd
# - Sex(Gender) : Male, Female
# - Age : Age in years
# - SibSp : Number of siblings/spouses abroad the titanic
# - Parch : Number of parents/children abrod the titanic
# - Ticket : Ticket Number
# - Fare : Passenger fare
# - Cabin : Cabin Number
# - Embarked : Port of Embarkation, C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # Q1: Print first and last rows from the dataset

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  people sur  people surt
# 0      man        True  NaN  Southampton    no  False       False        False
# 1    woman       False    C    Cherbourg   yes  False        True         True
# 2    woman       False  NaN  Southampton   yes   True        True         True
# 3    woman       False    C  Southampton   yes  False        True         True
# 4      man        True  NaN  Southampton    no   True       False        False
# ..     ...         ...  ...          ...   ...    ...         ...          ...
# 886    man        True  NaN  Southampton    no   True       False        False
# 887  woman       False    B  Southampton   yes   True        True         True
# 888  woman       False  NaN  Southampton    no  False       False        False
# 889    man        True    C    Cherbourg   yes   True        True         True
# 890    man        True  NaN   Queenstown    no   True       False        False
#
# [891 rows x 17 columns]

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df.tail(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 890         0       3  male  32.0      0      0  7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 890        True  NaN  Queenstown    no   True

# %% [markdown]
# # Q2: Select only survived people

# %%
df.loc[df['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone  people sur  people surt
# 1    woman       False    C    Cherbourg   yes  False        True         True
# 2    woman       False  NaN  Southampton   yes   True        True         True
# 3    woman       False    C  Southampton   yes  False        True         True
# 8    woman       False  NaN  Southampton   yes  False        True         True
# 9    child       False  NaN    Cherbourg   yes  False        True         True
# ..     ...         ...  ...          ...   ...    ...         ...          ...
# 875  child       False  NaN    Cherbourg   yes   True        True         True
# 879  woman       False    C    Cherbourg   yes  False        True         True
# 880  woman       False  NaN  Southampton   yes  False        True         True
# 887  woman       False    B  Southampton   yes   True        True         True
# 889    man        True    C    Cherbourg   yes   True        True         True
#
# [342 rows x 17 columns]

# %% [markdown]
# # Q3: Select sex, fare, survived columns

# %%
df[["sex", "fare","survived"]]
# Out:
#         sex     fare  survived
# 0      male   7.2500         0
# 1    female  71.2833         1
# 2    female   7.9250         1
# 3    female  53.1000         1
# 4      male   8.0500         0
# ..      ...      ...       ...
# 886    male  13.0000         0
# 887  female  30.0000         1
# 888  female  23.4500         0
# 889    male  30.0000         1
# 890    male   7.7500         0
#
# [891 rows x 3 columns]

# %% [markdown]
# # Q4: Add a new_column to a DataFrame that combines class and embark_town

# %%
df["New_cloumn"] = df["class"].str.cat(df["embark_town"], sep = "-")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  people sur  \
# 0      man        True  NaN  Southampton    no  False       False
# 1    woman       False    C    Cherbourg   yes  False        True
# 2    woman       False  NaN  Southampton   yes   True        True
# 3    woman       False    C  Southampton   yes  False        True
# 4      man        True  NaN  Southampton    no   True       False
# ..     ...         ...  ...          ...   ...    ...         ...
# 886    man        True  NaN  Southampton    no   True       False
# 887  woman       False    B  Southampton   yes   True        True
# 888  woman       False  NaN  Southampton    no  False       False
# 889    man        True    C    Cherbourg   yes   True        True
# 890    man        True  NaN   Queenstown    no   True       False
#
#      people surt          New_cloumn
# 0          False   Third-Southampton
# 1           True     First-Cherbourg
# 2           True   Third-Southampton
# 3           True   First-Southampton
# 4          False   Third-Southampton
# ..           ...                 ...
# 886        False  Second-Southampton
# 887         True   First-Southampton
# 888        False   Third-Southampton
# 889         True     First-Cherbourg
# 890        False    Third-Queenstown
#
# [891 rows x 18 columns]

# %% [markdown]
# # Q5: Remove new_column from the DataFrame

# %%
del df["New_cloumn"]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  people sur  people surt
# 0      man        True  NaN  Southampton    no  False       False        False
# 1    woman       False    C    Cherbourg   yes  False        True         True
# 2    woman       False  NaN  Southampton   yes   True        True         True
# 3    woman       False    C  Southampton   yes  False        True         True
# 4      man        True  NaN  Southampton    no   True       False        False
# ..     ...         ...  ...          ...   ...    ...         ...          ...
# 886    man        True  NaN  Southampton    no   True       False        False
# 887  woman       False    B  Southampton   yes   True        True         True
# 888  woman       False  NaN  Southampton    no  False       False        False
# 889    man        True    C    Cherbourg   yes   True        True         True
# 890    man        True  NaN   Queenstown    no   True       False        False
#
# [891 rows x 17 columns]

# %% [markdown]
# # Q6: Filter DataFrame for rows of survived Males only

# %%
df.loc[(df['survived'] == 1) & (df['sex'] == 'male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone  people sur  people surt
# 17     man        True  NaN  Southampton   yes   True        True         True
# 21     man        True    D  Southampton   yes   True        True         True
# 23     man        True    A  Southampton   yes   True        True         True
# 36     man        True  NaN    Cherbourg   yes   True        True         True
# 55     man        True    C  Southampton   yes   True        True         True
# ..     ...         ...  ...          ...   ...    ...         ...          ...
# 838    man        True  NaN  Southampton   yes   True        True         True
# 839    man        True    C    Cherbourg   yes   True        True         True
# 857    man        True    E  Southampton   yes   True        True         True
# 869  child       False  NaN  Southampton   yes  False        True         True
# 889    man        True    C    Cherbourg   yes   True        True         True
#
# [109 rows x 17 columns]

# %%
# Out:
# 919

# %% [markdown]
# # Q7: The total number of males who survived

# %%
x= len(df[(df['survived']== 1 ) & (df['sex']== 'male')])
x
# Out:
# 109

# %% [markdown]
# # Q8: How many values in each class?

# %%
df['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Q9: Draw barplot represents survived people based on sex

# %%
sns.barplot(data=df, x="sex", y="survived")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %% [markdown]
# # Q10: Draw catplot represents survived people based on embarked

# %%
sns.catplot(data=df, x="embarked", y="survived", kind="box")

# %% [markdown]
# # Q11: Draw boxplot represents distribution of male and female based on age and pclass

# %%
sns.boxplot(data=df, x="pclass", y="age", hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# # Q12: Draw heatmap represents correlations between sibsp, parch, age, fare, and survived columns

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q13: Draw factorplot represents the relation between sibsp and survived columns

# %%
sns.factorplot(x ='sibsp', y ='survived', data = df)

# %% [markdown]
# # Q14: Draw extra insights [Optional]

# %%
sns.catplot(x ="sex", hue ="survived",kind ="count", data = df)
