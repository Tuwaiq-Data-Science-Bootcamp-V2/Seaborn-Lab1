# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlite3
sns.set()

# %%
df = pd.read_csv("titanic.csv")

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ## Data Description
#
# - Survival : 0 = No, 1 = Yes
# - pclass(Ticket Class) : 1 = 1st, 2 = 2nd, 3 = 3rd
# - Sex(Gender) : Male, Female
# - Age : Age in years
# - SibSp : Number of siblings/spouses abroad the titanic
# - Parch : Number of parents/children abrod the titanic
# - Ticket : Ticket Number
# - Fare : Passenger fare
# - Cabin : Cabin Number
# - Embarked : Port of Embarkation, C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # Q1: Print first and last rows from the dataset

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# # Q2: Select only survived people

# %%
df.loc[df['survived']==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [342 rows x 15 columns]

# %% [markdown]
# # Q3: Select sex, fare, survived columns

# %%
df.loc[:,['survived','sex','fare']]
# Out:
#      survived     sex     fare
# 0           0    male   7.2500
# 1           1  female  71.2833
# 2           1  female   7.9250
# 3           1  female  53.1000
# 4           0    male   8.0500
# ..        ...     ...      ...
# 886         0    male  13.0000
# 887         1  female  30.0000
# 888         0  female  23.4500
# 889         1    male  30.0000
# 890         0    male   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# # Q4: Add a new_column to a DataFrame that combines class and embark_town

# %%
df['new_column']= df['class']+""+ df['embark_town']
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone         new_column
# 0      man        True  NaN  Southampton    no  False   ThirdSouthampton
# 1    woman       False    C    Cherbourg   yes  False     FirstCherbourg
# 2    woman       False  NaN  Southampton   yes   True   ThirdSouthampton
# 3    woman       False    C  Southampton   yes  False   FirstSouthampton
# 4      man        True  NaN  Southampton    no   True   ThirdSouthampton
# ..     ...         ...  ...          ...   ...    ...                ...
# 886    man        True  NaN  Southampton    no   True  SecondSouthampton
# 887  woman       False    B  Southampton   yes   True   FirstSouthampton
# 888  woman       False  NaN  Southampton    no  False   ThirdSouthampton
# 889    man        True    C    Cherbourg   yes   True     FirstCherbourg
# 890    man        True  NaN   Queenstown    no   True    ThirdQueenstown
#
# [891 rows x 16 columns]

# %% [markdown]
# # Q5: Remove new_column from the DataFrame

# %%
df.drop('new_column', axis='columns',inplace=True )
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # Q6: Filter DataFrame for rows of survived Males only

# %%
df.loc[df['sex']=='male']
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
df.loc[17:,['age','class']]
# Out:
#       age   class
# 17    NaN  Second
# 18   31.0   Third
# 19    NaN   Third
# 20   35.0  Second
# 21   34.0  Second
# ..    ...     ...
# 886  27.0  Second
# 887  19.0   First
# 888   NaN   Third
# 889  26.0   First
# 890  32.0   Third
#
# [874 rows x 2 columns]

# %% [markdown]
# # Q7: The total number of males who survived

# %%
df.groupby('sex').count()['survived']
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %% [markdown]
# # Q8: How many values in each class?

# %%
df['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Q9: Draw barplot represents survived people based on sex

# %%
sns.barplot(x='sex', y='survived',data=df);

# %% [markdown]
# # Q10: Draw catplot represents survived people based on embarked

# %%
y = sns.catplot(x="survived", col="embarked", 
               
                kind="count" ,data=df)

# %% [markdown]
# # Q11: Draw boxplot represents distribution of male and female based on age and pclass

# %%
sns.boxplot(x="sex", y="age", hue="pclass", data=df);

# %%
x=df.loc[:,['sibsp','parch','age','fare','survived']]
x
# Out:
#      sibsp  parch   age     fare  survived
# 0        1      0  22.0   7.2500         0
# 1        1      0  38.0  71.2833         1
# 2        0      0  26.0   7.9250         1
# 3        1      0  35.0  53.1000         1
# 4        0      0  35.0   8.0500         0
# ..     ...    ...   ...      ...       ...
# 886      0      0  27.0  13.0000         0
# 887      0      0  19.0  30.0000         1
# 888      1      2   NaN  23.4500         0
# 889      0      0  26.0  30.0000         1
# 890      0      0  32.0   7.7500         0
#
# [891 rows x 5 columns]

# %% [markdown]
# # Q12: Draw heatmap represents correlations between sibsp, parch, age, fare, and survived columns

# %%
new=x.corr()

y=sns.heatmap(data=new, cmap='Blues',annot=True)

# %% [markdown]
# # Q13: Draw factorplot represents the relation between sibsp and survived columns

# %%
sns.factorplot(x ='sibsp', y ='survived', data = df)
# Out:
# C:\Users\96650\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Q14: Draw extra insights [Optional]

# %%
sns.boxplot(df["age"]);
# Out:
# C:\Users\96650\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
