# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ## Data Description
#
# - Survival : 0 = No, 1 = Yes
# - pclass(Ticket Class) : 1 = 1st, 2 = 2nd, 3 = 3rd
# - Sex(Gender) : Male, Female
# - Age : Age in years
# - SibSp : Number of siblings/spouses abroad the titanic
# - Parch : Number of parents/children abrod the titanic
# - Ticket : Ticket Number
# - Fare : Passenger fare
# - Cabin : Cabin Number
# - Embarked : Port of Embarkation, C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # Q1: Print first and last rows from the dataset

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df.tail(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 890         0       3  male  32.0      0      0  7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 890        True  NaN  Queenstown    no   True

# %% [markdown]
# # Q2: Select only survived people

# %%
gag = df[(df['survived'] == 1)]
gag
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone          new_column
# 1    woman       False    C    Cherbourg   yes  False     First Cherbourg
# 2    woman       False  NaN  Southampton   yes   True   Third Southampton
# 3    woman       False    C  Southampton   yes  False   First Southampton
# 8    woman       False  NaN  Southampton   yes  False   Third Southampton
# 11   woman       False    C  Southampton   yes   True   First Southampton
# ..     ...         ...  ...          ...   ...    ...                 ...
# 871  woman       False    D  Southampton   yes  False   First Southampton
# 874  woman       False  NaN    Cherbourg   yes  False    Second Cherbourg
# 879  woman       False    C    Cherbourg   yes  False     First Cherbourg
# 880  woman       False  NaN  Southampton   yes  False  Second Southampton
# 889    man        True    C    Cherbourg   yes   True     First Cherbourg
#
# [208 rows x 16 columns]

# %%
gag.value_counts(['sex'])
# Out:
# sex
# female    233
# male      109
# dtype: int64

# %% [markdown]
# # Q3: Select sex, fare, survived columns

# %%
df2 = df[["sex","survived","fare"]]
df2
# Out:
#         sex  survived     fare
# 0      male         0   7.2500
# 1    female         1  71.2833
# 2    female         1   7.9250
# 3    female         1  53.1000
# 4      male         0   8.0500
# ..      ...       ...      ...
# 886    male         0  13.0000
# 887  female         1  30.0000
# 888  female         0  23.4500
# 889    male         1  30.0000
# 890    male         0   7.7500
#
# [891 rows x 3 columns]

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %% [markdown]
# # Q4: Add a new_column to a DataFrame that combines class and embark_town

# %%
df["new_column"] = df["class"].str.cat(df["embark_town"], sep=" ")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone          new_column
# 0      man        True  NaN  Southampton    no  False   Third Southampton
# 1    woman       False    C    Cherbourg   yes  False     First Cherbourg
# 2    woman       False  NaN  Southampton   yes   True   Third Southampton
# 3    woman       False    C  Southampton   yes  False   First Southampton
# 4      man        True  NaN  Southampton    no   True   Third Southampton
# ..     ...         ...  ...          ...   ...    ...                 ...
# 886    man        True  NaN  Southampton    no   True  Second Southampton
# 887  woman       False    B  Southampton   yes   True   First Southampton
# 888  woman       False  NaN  Southampton    no  False   Third Southampton
# 889    man        True    C    Cherbourg   yes   True     First Cherbourg
# 890    man        True  NaN   Queenstown    no   True    Third Queenstown
#
# [891 rows x 16 columns]

# %% [markdown]
# # Q5: Remove new_column from the DataFrame

# %%
df_pair = df.drop(['new_column'], axis=1)
df_pair
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [535 rows x 15 columns]

# %% [markdown]
# # Q6: Filter DataFrame for rows of survived Males only

# %%
new = df.loc[(df['survived'] == 1) & (df['sex'] == 'male')]
new
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 74          1       3  male  32.0      0      0  56.4958        S   Third
# 81          1       3  male  29.0      0      0   9.5000        S   Third
# 97          1       1  male  23.0      0      1  63.3583        C   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 804         1       3  male  27.0      0      0   6.9750        S   Third
# 821         1       3  male  27.0      0      0   8.6625        S   Third
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#      who  adult_male deck  embark_town alive  alone          new_column
# 21   man        True    D  Southampton   yes   True  Second Southampton
# 23   man        True    A  Southampton   yes   True   First Southampton
# 74   man        True  NaN  Southampton   yes   True   Third Southampton
# 81   man        True  NaN  Southampton   yes   True   Third Southampton
# 97   man        True    D    Cherbourg   yes  False     First Cherbourg
# ..   ...         ...  ...          ...   ...    ...                 ...
# 804  man        True  NaN  Southampton   yes   True   Third Southampton
# 821  man        True  NaN  Southampton   yes   True   Third Southampton
# 838  man        True  NaN  Southampton   yes   True   Third Southampton
# 857  man        True    E  Southampton   yes   True   First Southampton
# 889  man        True    C    Cherbourg   yes   True     First Cherbourg
#
# [64 rows x 16 columns]

# %% [markdown]
# # Q7: The total number of males who survived

# %%
new.value_counts(['sex'])
# Out:
# sex
# male    64
# dtype: int64

# %% [markdown]
# # Q8: How many values in each class?

# %%
df.value_counts(['class'])
# Out:
# class
# Third     232
# First     165
# Second    138
# dtype: int64

# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Q9: Draw barplot represents survived people based on sex

# %%
import numpy as np
sns.barplot(x='sex', y='survived',data =df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %% [markdown]
# # Q10: Draw catplot represents survived people based on embarked

# %%
g = sns.catplot(
    data=df, # Data
    kind="bar", # Chart to use
    x="embarked", # X axis
    y="survived", # y axis
    alpha=.8, # adjust transparancy
    height=5
)

# %% [markdown]
# # Q11: Draw boxplot represents distribution of male and female based on age and pclass

# %%
sns.boxplot(x="pclass", y="age",  hue="sex", data=df, palette='rainbow')

# %% [markdown]
# # Q12: Draw heatmap represents correlations between sibsp, parch, age, fare, and survived columns

# %%
df4 = newData[["sibsp","survived","fare",'age','parch']]
sns.heatmap(df4.corr())

# %% [markdown]
# # Q13: Draw factorplot represents the relation between sibsp and survived columns

# %%
sns.factorplot(x ='sibsp', y ='survived', data = df)

# %% [markdown]
# # Q14: Draw extra insights [Optional]

# %%
import matplotlib.pyplot as plt
##show how many survived from age 31
h = gag[(gag['age'] > 30)]
plt.figure(figsize=(30,10))

sns.countplot(x='age', data=h)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>
